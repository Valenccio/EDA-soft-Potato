# %% [markdown]
# IMPORT

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import seaborn as sbn
import random as rng
import math

# %%
df = pd.read_csv("ds_salaries.csv")
"""
Beberapa Notes untuk Kolom dataset tersebut adalah: 
1. work_year: Tahun dimana gajinya telah diberikan
2. experience_level: level experience / pengalaman dalam bidang pekerjaan
    field_value: {
        EN: Entry level                 1
        MI: Junior Mid Level            2
        SE: Intermediate Senior Level   3
        EX: Expert Executive Level      4
    }
3. employement_type: Tipe pekerja
    field_value: {
        PT: kerja paruh waktu           4
        FT: kerja fulltime              3
        CT: contract                    2
        FL: Freelance                   1
}
4. job_title: Job Title
5. salary: nilai gaji
6. salary_currency: nilai gaji tersebut dalam mata uang apa
7. salary_in_usd: gaji jika di ubah menjadi mata uang dollar
8. employee_residence: lokasi asal dari pekerja
9. remote_ratio: rasio pekerja bekerja secara jarak jauh
10. company_location: lokasi perusahaan pekerja
11. company_size: ukuran dari perusahaan berdasarkan dari jumlah pekerja di sana
    field_value{
        S: small (x<50),
        M: medium (50<=x<250),
        L: large (x>250),
}
"""

df = df.drop(columns="sam")
df
# Out:
#      num  work_year  ... company_location company_size
# 0      0       2020  ...               DE            L
# 1      1       2020  ...               JP            S
# 2      2       2020  ...               GB            M
# 3      3       2020  ...               HN            S
# 4      4       2020  ...               US            L
# ..   ...        ...  ...              ...          ...
# 602  602       2022  ...               US            M
# 603  603       2022  ...               US            M
# 604  604       2022  ...               US            M
# 605  605       2022  ...               US            M
# 606  606       2022  ...               US            L
#
# [607 rows x 12 columns]

# %%
sbn.boxplot(df["salary_in_usd"])
# Out:
# <Axes: ylabel='salary_in_usd'>

# %% [markdown]
# Membersihkan Outlier dan Keseluruhan Data

# %%
df = df.drop(["salary_currency"], axis=1)

q1 = df["salary_in_usd"].quantile(0.25) # Quartile 1
q3 = df["salary_in_usd"].quantile(0.75) # Quartile 3
iqr = q3-q1 # Inter Quartile Range

low_lim = q1 - 1.5*iqr
hi_lim = q3 + 1.5*iqr

print(f"{low_lim}, {hi_lim}")

for i in range(len(df["salary_in_usd"])):
    if hi_lim < df["salary_in_usd"][i]:
        df = df.drop([i])

sbn.boxplot(df["salary_in_usd"])
# Out:
# -68185.0, 280911.0
# <Axes: ylabel='salary_in_usd'>

# %%
df = df.reset_index()

df = df.drop(columns="num")

# Mengubah Kategorikal
df["company_size"] = df["company_size"].apply(lambda x: 1 if x == "S" else x)
df["company_size"] = df["company_size"].apply(lambda x: 2 if x == "M" else x)
df["company_size"] = df["company_size"].apply(lambda x: 3 if x == "L" else x)



df["experience_level"] = df["experience_level"].apply(lambda x: 1 if x == "EN" else x)
df["experience_level"] = df["experience_level"].apply(lambda x: 2 if x == "MI" else x)
df["experience_level"] = df["experience_level"].apply(lambda x: 3 if x == "SE" else x)
df["experience_level"] = df["experience_level"].apply(lambda x: 4 if x == "EX" else x)

df["employment_type"] = df["employment_type"].apply(lambda x: 4 if x == "FT" else x)
df["employment_type"] = df["employment_type"].apply(lambda x: 3 if x == "PT" else x)
df["employment_type"] = df["employment_type"].apply(lambda x: 2 if x == "CT" else x)
df["employment_type"] = df["employment_type"].apply(lambda x: 1 if x == "FL" else x)

df.describe()
# Out:
#             index    work_year  ...  remote_ratio  company_size
# count  597.000000   597.000000  ...    597.000000    597.000000
# mean   304.095477  2021.412060  ...     70.686767      2.182580
# std    174.888716     0.688634  ...     40.797800      0.651661
# min      0.000000  2020.000000  ...      0.000000      1.000000
# 25%    153.000000  2021.000000  ...     50.000000      2.000000
# 50%    305.000000  2022.000000  ...    100.000000      2.000000
# 75%    454.000000  2022.000000  ...    100.000000      3.000000
# max    606.000000  2022.000000  ...    100.000000      3.000000
#
# [8 rows x 8 columns]

# %% [markdown]
# Data Splitting

# %%
dataset = np.log1p(df[["salary_in_usd"]].values)

train_size = round(len(df["salary_in_usd"]) - len(df["salary_in_usd"])*0.75)


data_train, data_test = dataset[0:train_size,:], dataset[train_size:len(dataset), :]

print(data_train.shape)
print(data_test.shape)
# Out:
# (149, 1)
# (448, 1)

# %%
def create_dataset(data, look_back = 1):
    datax, datay = [], []
    for i in range(len(data) - look_back - 1):
        a = data[i:(i+look_back), 0]
        datax.append(a)
        datay.append(data[i+ look_back, 0])
    return np.array(datax), np.array(datay)

once = 1
trainX, trainY = create_dataset(data_train, once)
testX, testY = create_dataset(data_test, once)


print(f"shape: trX: {trainX.shape}, trY: {trainY.shape}, teX: {testX.shape}, teY: {trainY.shape}")
# Out:
# shape: trX: (147, 1), trY: (147,), teX: (446, 1), teY: (147,)

# %%
trainX = np.reshape(trainX, (trainX.shape[0],1,trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0],1,testX.shape[1]))

print(testX.shape)
print(trainX.shape)
print("\n")
print(testY.shape)
print(trainY.shape)
# Out:
# (446, 1, 1)
# (147, 1, 1)
#
#
# (446,)
# (147,)

# %% [markdown]
# Implementasi Machine Learning

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM
from sklearn.metrics import mean_squared_error

# %%
#LSTM

model = Sequential()
model.add(LSTM(4, input_shape=(1, once)))
model.add(Dense(1))

model.compile(loss= 'mean_squared_error', optimizer="adam")
model.fit(trainX,trainY,epochs=500, batch_size=32, verbose=2)
# Out:
# Epoch 1/500
# c:\Users\Nur Hary\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 5/5 - 1s - 295ms/step - loss: 112.8237
# Epoch 2/500
# 5/5 - 0s - 12ms/step - loss: 112.0315
# Epoch 3/500
# 5/5 - 0s - 17ms/step - loss: 111.2458
# Epoch 4/500
# 5/5 - 0s - 17ms/step - loss: 110.4631
# Epoch 5/500
# 5/5 - 0s - 15ms/step - loss: 109.6882
# Epoch 6/500
# 5/5 - 0s - 11ms/step - loss: 108.9215
# Epoch 7/500
# 5/5 - 0s - 11ms/step - loss: 108.1609
# Epoch 8/500
# 5/5 - 0s - 10ms/step - loss: 107.4062
# Epoch 9/500
# 5/5 - 0s - 12ms/step - loss: 106.6632
# Epoch 10/500
# 5/5 - 0s - 12ms/step - loss: 105.9282
# Epoch 11/500
# 5/5 - 0s - 11ms/step - loss: 105.2017
# Epoch 12/500
# 5/5 - 0s - 11ms/step - loss: 104.4832
# Epoch 13/500
# 5/5 - 0s - 10ms/step - loss: 103.7757
# Epoch 14/500
# 5/5 - 0s - 10ms/step - loss: 10.4979
# Epoch 345/500
# 5/5 - 0s - 10ms/step - loss: 10.4186
# Epoch 346/500
# 5/5 - 0s - 16ms/step - loss: 10.3415
# Epoch 347/500
# 5/5 - 0s - 9ms/step - loss: 10.2645
# Epoch 348/500
# 5/5 - 0s - 10ms/step - loss: 10.1873
# Epoch 349/500
# 5/5 - 0s - 10ms/step - loss: 10.1114
# Epoch 350/500
# 5/5 - 0s - 10ms/step - loss: 10.0350
# Epoch 351/500
# 5/5 - 0s - 10ms/step - loss: 9.9603
# Epoch 352/500
# 5/5 - 0s - 10ms/step - loss: 9.8853
# Epoch 353/500
# 5/5 - 0s - 10ms/step - loss: 9.8112
# Epoch 354/500
# 5/5 - 0s - 10ms/step - loss: 9.7373
# Epoch 355/500
# 5/5 - 0s - 10ms/step - loss: 9.6640
# Epoch 356/500
# 5/5 - 0s - 10ms/step - loss: 9.5902
# Epoch 357/500
# 5/5 - 0s - 10ms/step - loss: 9.5184
# Epoch 358/500
# 5/5 - 0s - 10ms/step - loss: 9.4452
# Epoch 359/500
# 5/5 - 0s - 15ms/step - loss: 9.3745
# Epoch 360/500
# 5/5 - 0s - 10ms/step - loss: 9.3033
# Epoch 361/500
# 5/5 - 0s - 9ms/step - loss: 9.2326
# Epoch 362/500
# 5/5 - 0s - 10ms/step - loss: 9.1625
# Epoch 363/500
# 5/5 - 0s - 10ms/step - loss: 9.0922
# Epoch 364/500
# 5/5 - 0s - 10ms/step - loss: 9.0228
# Epoch 365/500
# 5/5 - 0s - 10ms/step - loss: 8.9541
# Epoch 366/500
# 5/5 - 0s - 10ms/step - loss: 8.8858
# Epoch 367/500
# 5/5 - 0s - 10ms/step - loss: 8.8173
# Epoch 368/500
# 5/5 - 0s - 10ms/step - loss: 8.7500
# Epoch 369/500
# 5/5 - 0s - 10ms/step - loss: 8.6828
# Epoch 370/500
# 5/5 - 0s - 10ms/step - loss: 8.6166
# Epoch 371/500
# 5/5 - 0s - 9ms/step - loss: 8.5494
# Epoch 372/500
# 5/5 - 0s - 10ms/step - loss: 8.4827
# Epoch 373/500
# 5/5 - 0s - 9ms/step - loss: 8.4180
# Epoch 374/500
# 5/5 - 0s - 9ms/step - loss: 8.3520
# Epoch 375/500
# 5/5 - 0s - 10ms/step - loss: 8.2877
# Epoch 376/500
# 5/5 - 0s - 10ms/step - loss: 8.2224
# Epoch 377/500
# 5/5 - 0s - 10ms/step - loss: 8.1597
# Epoch 378/500
# 5/5 - 0s - 10ms/step - loss: 8.0952
# Epoch 379/500
# 5/5 - 0s - 10ms/step - loss: 8.0318
# Epoch 380/500
# 5/5 - 0s - 9ms/step - loss: 7.9692
# Epoch 381/500
# 5/5 - 0s - 10ms/step - loss: 7.9070
# Epoch 382/500
# 5/5 - 0s - 10ms/step - loss: 7.8459
# Epoch 383/500
# 5/5 - 0s - 10ms/step - loss: 7.7835
# Epoch 384/500
# 5/5 - 0s - 9ms/step - loss: 7.7225
# Epoch 385/500
# 5/5 - 0s - 16ms/step - loss: 7.6617
# 5/5 - 0s - 10ms/step - loss: 3.8705
# Epoch 469/500
# 5/5 - 0s - 10ms/step - loss: 3.8371
# Epoch 470/500
# 5/5 - 0s - 10ms/step - loss: 3.8050
# Epoch 471/500
# 5/5 - 0s - 10ms/step - loss: 3.7731
# Epoch 472/500
# 5/5 - 0s - 10ms/step - loss: 3.7406
# Epoch 473/500
# 5/5 - 0s - 11ms/step - loss: 3.7093
# Epoch 474/500
# 5/5 - 0s - 11ms/step - loss: 3.6777
# Epoch 475/500
# 5/5 - 0s - 10ms/step - loss: 3.6467
# Epoch 476/500
# 5/5 - 0s - 9ms/step - loss: 3.6161
# Epoch 477/500
# 5/5 - 0s - 10ms/step - loss: 3.5854
# Epoch 478/500
# 5/5 - 0s - 10ms/step - loss: 3.5553
# Epoch 479/500
# 5/5 - 0s - 11ms/step - loss: 3.5251
# Epoch 480/500
# 5/5 - 0s - 11ms/step - loss: 3.4949
# Epoch 481/500
# 5/5 - 0s - 10ms/step - loss: 3.4655
# Epoch 482/500
# 5/5 - 0s - 10ms/step - loss: 3.4360
# Epoch 483/500
# 5/5 - 0s - 10ms/step - loss: 3.4072
# Epoch 484/500
# 5/5 - 0s - 10ms/step - loss: 3.3781
# Epoch 485/500
# 5/5 - 0s - 10ms/step - loss: 3.3500
# Epoch 486/500
# 5/5 - 0s - 10ms/step - loss: 3.3216
# Epoch 487/500
# 5/5 - 0s - 10ms/step - loss: 3.2929
# Epoch 488/500
# 5/5 - 0s - 10ms/step - loss: 3.2655
# Epoch 489/500
# 5/5 - 0s - 10ms/step - loss: 3.2380
# Epoch 490/500
# 5/5 - 0s - 10ms/step - loss: 3.2102
# Epoch 491/500
# 5/5 - 0s - 11ms/step - loss: 3.1830
# Epoch 492/500
# 5/5 - 0s - 11ms/step - loss: 3.1566
# Epoch 493/500
# 5/5 - 0s - 12ms/step - loss: 3.1295
# Epoch 494/500
# 5/5 - 0s - 17ms/step - loss: 3.1034
# Epoch 495/500
# 5/5 - 0s - 14ms/step - loss: 3.0765
# Epoch 496/500
# 5/5 - 0s - 13ms/step - loss: 3.0510
# Epoch 497/500
# 5/5 - 0s - 13ms/step - loss: 3.0252
# Epoch 498/500
# 5/5 - 0s - 13ms/step - loss: 2.9996
# Epoch 499/500
# 5/5 - 0s - 12ms/step - loss: 2.9741
# Epoch 500/500
# 5/5 - 0s - 12ms/step - loss: 2.9490

# %%
train_predict = model.predict(trainX)
test_predict = model.predict(testX)

train_predict = np.expm1(train_predict)
trainY = np.expm1(trainY)
test_predict = np.expm1(test_predict)
testY = np.expm1(testY)

trainscore = math.sqrt(mean_squared_error(trainY, train_predict[:,0]))
testscore = math.sqrt(mean_squared_error(testY, test_predict[:,0]))

print(f"train: {trainscore}, test: {testscore}")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# train: 96133.04765761172, test: 112507.69558795936

# %%
series = pd.Series(testY)

if testscore < series.std():
    print("Performa model cukup bagus")
    print(f"{testscore} < {series.std()}")
else:
    print("Performa model tidak cukup bagus")
    print(f"{testscore} > {series.std()}")
# Out:
# Performa model tidak cukup bagus
# 112507.69558795936 > 57102.92618223756
